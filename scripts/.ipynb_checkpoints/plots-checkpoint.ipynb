# %%
from proj1_helpers import *
from implementations import *
from preprocessing import *
import numpy as np
import matplotlib.pyplot as plt

# %%
# Read train_y=LABELS, train_x=FEATURES and train_id=EVENT_IDS from dataset.
subsamp = False
y, x, id_ = load_csv_data('../data/train.csv', sub_sample=subsamp)
y_out_test, x_out_test, id_out_test = load_csv_data('../data/test.csv', sub_sample=subsamp)

# %%
def pca(x, max_comp=30):
    """PCA on the design matrix x.

    Returns the new design matrix with vectors transformed to eigenspace of covariance matrix and the transformation matrix."""

    covariance_matrix = np.cov(x.T)
    eigenvals, eigenvect = np.linalg.eig(covariance_matrix)
    rank_eigenvals = sorted(eigenvals, reverse=True)
    val_vect_couples = {val:vect for val, vect in zip(eigenvals, eigenvect)}
    rank_eigenvects = [val_vect_couples[val] for val in rank_eigenvals]
    diagonal2original = np.vstack(eigenvect[:max_comp])
    new_x = x.dot(diagonal2original)
    return new_x, diagonal2original
def preprocess(x, y, clean=True, dopca=True, max_comp = 30):
    """Preprocess raw data.

    Standardizes data and optionally cleans and/or does pca. Returns cleaned data, design matrix, original mean and standard deviation of x and transformation matrix (if PCA was done else None)."""
    work_x = np.copy(x)
    work_y = np.copy(y)
    if clean:
        y_clean, x_clean = clean_data(work_y, work_x)
    else:
        y_clean, x_clean = work_y, work_x
    x_clean, x_mean, x_var = standardize_features(x_clean)
    if dopca:
        x_clean, transform = pca(x_clean, max_comp=max_comp)
    else:
        transform = None
    return y_clean, x_clean, x_mean, x_var, transform

# %%
def plot_distributions(x, ax, **kwargs):
    for i in range(x.shape[1]):
        ax.hist(x[:,i], bins =20, **kwargs, histtype='step')
def imshow_data(data, ax=None):
    fig = ax.figure
    c = ax.imshow(data, aspect='auto')
    fig.colorbar(c, ax=ax)

    
def plot_prep_steps(x, y, plot_func):
    fig, ax = plt.subplots(2, 2, figsize = (20, 10))
    bools = [True,False]
    for cl in bools:
        for pc in bools:
            this_ax = ax[int(cl), int(pc)]
            this_y, this_x, this_x_mean, this_x_std, _ = preprocess(x, y, clean = cl, dopca=pc)
            plot_func(this_x, this_ax)
            this_ax.set_title('Clean = %s, PCA = %s'%(cl, pc))

# %%
plot_prep_steps(x, y, imshow_data)

# %%
plot_prep_steps(x, y, plot_distributions)

# %%
fig = plt.figure()
plot_distributions(x, plt.gca())
print((x==-999).any())
# Out:
# True

# %%
plt.imshow(x==-999, aspect='auto')

# %%
nan_rows, nan_cols = np.where(x == -999)
y_hist, x_hist, _ = plt.hist(nan_cols,
                             bins=60,
                             weights=np.ones(len(nan_cols)) / len(y),
                             rwidth=0.7)
plt.xlabel('Column number')
plt.ylabel('Fraction of NaN data')
nan_cols_set = list(set(nan_cols))
col_ids = [plt.axvline(col_no, c='k', ls=':', lw=1) for col_no in range(30)]

# %%
plt.hist(nan_rows, bins=30, weights = np.ones(len(nan_cols))/len(y))
plt.xlabel('Row number')
plt.ylabel('Fraction of NaN data')
# Out:
# Text(0, 0.5, 'Fraction of NaN data')

# %%
f = plt.figure()
imshow_data(np.cov(x.T), plt.gca())

# %%
bools = [True,False]
cov_mat_plot, cov_plot_ax = plt.subplots(2, 2, figsize = (20, 10))
for cl in bools:
    for pc in bools:
        this_ax = cov_plot_ax[int(cl), int(pc)]
        this_y, this_x, this_x_mean, this_x_std, _ = preprocess(x, y, clean = cl, dopca=pc)
        C = np.cov(this_x.T)
        imshow_data(C, this_ax)
        this_ax.set_title('Covmat: Clean = %s, PCA = %s'%(cl, pc))

# %%
cov_mat_plot, cov_plot_ax = plt.subplots(1, 2, figsize = (20, 5))
for cl in bools:
    pc = True
    this_ax = cov_plot_ax[int(cl)]
    this_y, this_x, this_x_mean, this_x_std, transform = preprocess(x, y, clean = cl, dopca=pc)
    C = np.cov(this_x.T)
    imshow_data(transform.dot(C).dot(np.linalg.inv(transform)), this_ax)
    this_ax.set_title('Clean = %s, PCA = %s'%(cl, pc))

# %%
std_feature_plot, std_feature_ax = plt.subplots(1, 2, figsize = (15, 5))
for cl in bools:
    pc= False #This doesnt affect the result
    this_ax = std_feature_ax[int(cl)]
    this_y, this_x, this_x_mean, this_x_std, _ = preprocess(x, y, clean = cl, dopca=pc)
    this_ax.bar(range(30),this_x_std)
    [this_ax.axvline(col, c = 'k', ls= ':', lw =1) for col in nan_cols_set]
    this_ax.set_title('Standard Deviation: Clean = %s, PCA = %s'%(cl, pc))

# %%
mean_feature_plot, mean_feature_ax = plt.subplots(1, 2, figsize = (15, 5), sharey=True)
for cl in bools:
    pc= False #This doesnt affect the result
    this_ax = mean_feature_ax[int(cl)]
    this_y, this_x, this_x_mean, this_x_std, _ = preprocess(x, y, clean = cl, dopca=pc)
    this_ax.bar(range(30),abs(this_x_mean))
    [this_ax.axvline(col, c = 'k', ls= ':', lw =1) for col in nan_cols_set]
    this_ax.set_title('Mean: Clean = %s, PCA = %s'%(cl, pc))

# %%
two_feature_plot, two_feature_ax = plt.subplots(1, 2, figsize = (15, 5), sharey=True)
for cl in bools:
    pc= True #This doesnt affect the result
    this_ax = two_feature_ax[int(cl)]
    this_y, this_x, this_x_mean, this_x_std, _ = preprocess(x, y, clean = cl, dopca=pc, max_comp=3)
    std_this_x, _, _ = standardize_features(this_x)
    this_ax.scatter(std_this_x[:,1], std_this_x[:,2], c = this_y)
    this_ax.set_title('Features: Clean = %s, PCA = %s'%(cl, pc))
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-208-d191fd32de62> in <module>
#       3     pc= True #This doesnt affect the result
#       4     this_ax = two_feature_ax[int(cl)]
# ----> 5     this_y, this_x, this_x_mean, this_x_std, _ = preprocess(x, y, clean = cl, dopca=pc, max_comp=3)
#       6     std_this_x, _, _ = standardize_features(this_x)
#       7     this_ax.scatter(std_this_x[:,1], std_this_x[:,2], c = this_y)
#
# <ipython-input-201-e121fee8d080> in preprocess(x, y, clean, dopca, max_comp)
#      24     x_clean, x_mean, x_var = standardize_features(x_clean)
#      25     if dopca:
# ---> 26         x_clean, transform = pca(x_clean, max_comp=max_comp)
#      27     else:
#      28         transform = None
#
# <ipython-input-201-e121fee8d080> in pca(x, max_comp)
#      10     rank_eigenvects = [val_vect_couples[val] for val in rank_eigenvals]
# ...
